# %% [markdown]
# # Portfolio Construction Results
# Feb-7-2017
# Baruch MFE Investment
# Author: Derek Qi
#
# ## Data scrubling
# Taking the filtered pool of 1822 stocks, estimated factor return and factor covariance, running through the GenReturn process by Zilun and my optimizer, I came with the following portfolio
#
# ## Long only portfolio
# These portfolios could serve as our initial portfolio to start with.
# ### Portfolio Components
# |Ticker|Weight|
# |---|---|
# |NTLS|0.1906711033|
# |MDAS|0.1882057851|
# |KING|0.1592596179|
# |DYAX|0.1440577358|
# |TSYS|0.1291798647|
# |SYA|0.1074150581|
# |OCAT|0.0812108351|
#
# 7 securities passed the screen.
#
# ### Optimization Details
# - w_old is set at all equally weighted long.
# - $gamma$ (risk parameter) is 1
# - $lambda$ (trading cost parameter) is 0. (non-binding)
# - Lower bound is -1. (non-binding)
# - Upper bound is 1. (non-binding)
# - $delta$ (position change bound) is 1 (non-binding)
# - Screen out all the secirities with weight < $10^{-4}$, and re-normalize
#
# ## Long-short portfolio
# These portfolios could serve as our initial portfolio to start with.
# ### Portfolio Components
# |Ticker|Weight|
# |---|---|
# |NTLS|0.260771798|
# |MDAS|0.248765927|
# |TSYS|0.2239833181|
# |KING|0.216333345|
# |DYAX|0.1887779353|
# |SYA|0.1733198773|
# |OCAT|0.1698894479|
# |BDBD|0.088659572|
# |PNY|0.0736846729|
# |1448479D|0.0479740932|
# |PMCS|0.0478967129|
# |BMR|0.0475195561|
# |ARG|0.0442109424|
# |ULTA|0.033274326|
# |OVTI|0.0330993277|
# |GAS|0.0312659641|
# |HPY|0.0288095134|
# |NUAN|0.0252738132|
# |MSCI|0.0164550992|
# |KWKAQ|-0.0161537333|
# |SUNEQ|-0.0232668566|
# |CMRX|-0.023605476|
# |WLTGQ|-0.0279589398|
# |ULTR|-0.0316112043|
# |GSIH|-0.0321544802|
# |MCPIQ|-0.0330310198|
# |MHRCQ|-0.05105927|
# |WTSLQ|-0.062423409|
# |VRSZQ|-0.0744568934|
# |FXCM|-0.0838904397|
# |SFYWQ|-0.1204337698|
# |BPZRQ|-0.1516541054|
# |MDWCQ|-0.2682656445|
#
# 33 securities altogether, 19 long positions and 14 short positions.
#
# ### Optimization Details
# - w_old is set at all equally weighted long.
# - $gamma$ (risk parameter) is 1
# - $lambda$ (trading cost parameter) is 0. (non-binding)
# - Lower bound is -1. (non-binding)
# - Upper bound is 1. (non-binding)
# - $delta$ (position change bound) is 1 (non-binding)
# - Leverage bound is fixed at 3
# - Screen out all the secirities with abs(weight) < $10^{-4}$, and re-normalize
